# %% [markdown]
# # AttnLRP (lxt) for ViLT

# %% [markdown]
# ## Setup

# %%
import torch
import requests
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
from lxt.utils import pdf_heatmap

# %%
# just a helper function to draw the text attention later
import html
import matplotlib
from matplotlib.colors import Normalize, to_hex

def colorize(tokens:list[str], weights:list[float], target:str=None):
    """returns a html heatmap representation of the tokens colored by weights.
        tokens and weights should match in lenghth
        target is optionally the token the weights were calculated for
    """
    template = '<span style="color: black; background-color: {}">{}</span>'
    colors = map(to_hex, matplotlib.colormaps['bwr'](Normalize(vmin=-1, vmax=1)(weights)))
    colored_output = ''
    for token, color in zip(tokens, colors):
        colored_output += template.format(color, '&nbsp'+html.escape(token)+'&nbsp')
    if target:
        colored_output += template.format('lime', '&nbsp'+html.escape(target)+'&nbsp')
    return HTML(colored_output)

# %% [markdown]
# ## Max Logit Attribution

# %% [markdown]
# ### Prepare Model

# %%
# load original ViLT processor
from transformers import ViltProcessor
# load adapted ViLT model and rule composite from attnLRP (lxt library)
from lxt.explicit.models.vilt import ViltForQuestionAnswering, attnlrp as lrp_rule_composite

# init processor (combines image patching and text tokenizers)
processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# still use original weights checkpoint from huggingface (from_pretrained)
adapted_model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# there is multiple ways to modify the model to compute relevance
# here part of the model was directly modified in code, part handled by automatic lrp rules, which we now apply
lrp_rule_composite.register(adapted_model);

# %% [markdown]
# ### Prepare Sample

# %%
# prepare an input sample, for illustration just an image from MSCOCO and a made up question
image = Image.open(requests.get("http://images.cocodataset.org/val2017/000000039769.jpg", stream=True).raw)
question = "Are those cats or dogs?"
inputs = processor(image, question, return_tensors="pt")
txt_tokens = processor.tokenizer.batch_decode(inputs.input_ids[0])

display(image)
print(txt_tokens)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>
# ['[CLS]', 'are', 'those', 'cats', 'or', 'dogs', '?', '[SEP]']

# %% [markdown]
# ### Setup Relevance Map

# %%
# attnLRP modifies the backward pass gradient computation to instead compute relevance
# thus enable gradient for all inputs which should receive a relevance map
inputs.pixel_values.requires_grad = True

# the token -> embedding step is a lookup table which is non-differentiable
# thus we compute the relevance for the embeddings instead and sum it up later (all relevance on the embedding is for the token)
# huggingface allows to pass the embeddings directly instead of token indices
inputs_embeds = adapted_model.get_input_embeddings()(inputs.input_ids)
inputs_embeds.requires_grad = True

# %% [markdown]
# ### Run Forward Pass

# %%
# forward pass
outputs = adapted_model(inputs_embeds=inputs_embeds, 
             pixel_values=inputs.pixel_values, 
             token_type_ids=inputs.token_type_ids, 
             attention_mask=inputs.attention_mask, 
             pixel_mask=inputs.pixel_mask)

# the max logit index marks the models' answer
logits = outputs.logits
max_logit, predicted_label_idx = logits.max(-1)

# we can look up the answer in the label list
predicted_label = adapted_model.config.id2label[predicted_label_idx.item()]
print("Question:", txt_tokens)
print("Predicted answer:", predicted_label)
# Out:
# Question: ['[CLS]', 'are', 'those', 'cats', 'or', 'dogs', '?', '[SEP]']
# Predicted answer: cats

# %% [markdown]
# ### Run Backward Pass (Attribution/Relevance Computation)

# %%
# to attribute the logit's value back to the inputs, we run the backward pass through it
max_logit.backward()

# since attnLRP modified the gradient computation we can now read the relevance off the .grad attribute
img_attention_map = inputs.pixel_values.grad[0].sum(0) # sum over RGB channels for per-pixel relevance
txt_attention_map = inputs_embeds.grad[0].sum(-1) # sum over embedding dim for per-token relevance

# normalize the maps to [-1, 1]
img_attention_map = img_attention_map / abs(img_attention_map).max()
txt_attention_map = txt_attention_map / abs(txt_attention_map).max()

# %%
plt.title(f"{question} - {predicted_label}")
plt.imshow(img_attention_map, cmap='bwr', vmin=-1, vmax=1)
plt.show()
colorize(txt_tokens, txt_attention_map, predicted_label)
# Out:
# <span style="color: black; background-color: #9c9cff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ececff">&nbspare&nbsp</span><span style="color: black; background-color: #e6e6ff">&nbspthose&nbsp</span><span style="color: black; background-color: #3636ff">&nbspcats&nbsp</span><span style="color: black; background-color: #0000ff">&nbspor&nbsp</span><span style="color: black; background-color: #2a2aff">&nbspdogs&nbsp</span><span style="color: black; background-color: #f8f8ff">&nbsp?&nbsp</span><span style="color: black; background-color: #fafaff">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspcats&nbsp</span>

# %% [markdown]
# ### We can also attribute other logits than the prediction

# %%
# forward pass
outputs = adapted_model(inputs_embeds=inputs_embeds, 
             pixel_values=inputs.pixel_values, 
             token_type_ids=inputs.token_type_ids, 
             attention_mask=inputs.attention_mask, 
             pixel_mask=inputs.pixel_mask)

logits = outputs.logits
alternative_label = 'dogs' # instead of max logit, we choose a custom logit
alternative_logit = logits[0, adapted_model.config.label2id[alternative_label]]

# to attribute the logit's value back to the inputs, we run the backward pass through it
alternative_logit.backward()

# since attnLRP modified the gradient computation we can now read the relevance off the .grad attribute
img_attention_map = inputs.pixel_values.grad[0].sum(0) # sum over RGB channels for per-pixel relevance
txt_attention_map = inputs_embeds.grad[0].sum(-1) # sum over embedding dim for per-token relevance

# normalize the maps to [-1, 1]
img_attention_map = img_attention_map / abs(img_attention_map).max()
txt_attention_map = txt_attention_map / abs(txt_attention_map).max()

# %%
plt.title(f"{question} - {alternative_label}")
plt.imshow(img_attention_map, cmap='bwr', vmin=-1, vmax=1)
plt.show()
colorize(txt_tokens, txt_attention_map)
# Out:
# <span style="color: black; background-color: #8080ff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ececff">&nbspare&nbsp</span><span style="color: black; background-color: #e6e6ff">&nbspthose&nbsp</span><span style="color: black; background-color: #2e2eff">&nbspcats&nbsp</span><span style="color: black; background-color: #0000ff">&nbspor&nbsp</span><span style="color: black; background-color: #2c2cff">&nbspdogs&nbsp</span><span style="color: black; background-color: #f8f8ff">&nbsp?&nbsp</span><span style="color: black; background-color: #fafaff">&nbsp[SEP]&nbsp</span>

# %% [markdown]
# ### ...or with contrastive target (why dog and not cat)

# %%
# forward pass
outputs = adapted_model(inputs_embeds=inputs_embeds, 
             pixel_values=inputs.pixel_values, 
             token_type_ids=inputs.token_type_ids, 
             attention_mask=inputs.attention_mask, 
             pixel_mask=inputs.pixel_mask)

logits = outpcuts.logits
max_logit, predicted_label_idx = logits.max(-1)
predicted_label = adapted_model.config.id2label[predicted_label_idx.item()]
alternative_label = 'dogs'
alternative_label_idx = adapted_model.config.label2id[alternative_label]

# to attribute multipe logits, we run backward and init the gradient with 1 (or -1 for contrast)
logit_mask = torch.zeros_like(logits)
logit_mask[0, predicted_label_idx] = 1
logit_mask[0, alternative_label_idx] = -1
logits.backward(logit_mask)

# since attnLRP modified the gradient computation we can now read the relevance off the .grad attribute
img_attention_map = inputs.pixel_values.grad[0].sum(0) # sum over RGB channels for per-pixel relevance
txt_attention_map = inputs_embeds.grad[0].sum(-1) # sum over embedding dim for per-token relevance

# normalize the maps to [-1, 1]
img_attention_map = img_attention_map / abs(img_attention_map).max()
txt_attention_map = txt_attention_map / abs(txt_attention_map).max()

# %%
plt.title(f"{question} - {predicted_label} vs. {alternative_label}")
plt.imshow(img_attention_map, cmap='bwr', vmin=-1, vmax=1)
plt.show()
colorize(txt_tokens, txt_attention_map)
# Out:
# <span style="color: black; background-color: #8080ff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ececff">&nbspare&nbsp</span><span style="color: black; background-color: #e6e6ff">&nbspthose&nbsp</span><span style="color: black; background-color: #2e2eff">&nbspcats&nbsp</span><span style="color: black; background-color: #0000ff">&nbspor&nbsp</span><span style="color: black; background-color: #2c2cff">&nbspdogs&nbsp</span><span style="color: black; background-color: #f8f8ff">&nbsp?&nbsp</span><span style="color: black; background-color: #fafaff">&nbsp[SEP]&nbsp</span>

# %% [markdown]
# ### ... or globally contrastive (why cat and not something else? = exclusive evidence for cat)

# %%
# forward pass
outputs = adapted_model(inputs_embeds=inputs_embeds, 
             pixel_values=inputs.pixel_values, 
             token_type_ids=inputs.token_type_ids, 
             attention_mask=inputs.attention_mask, 
             pixel_mask=inputs.pixel_mask)

logits = outputs.logits
max_logit, predicted_label_idx = logits.max(-1)
predicted_label = adapted_model.config.id2label[predicted_label_idx.item()]

# to attribute multipe logits, we run backward and init the gradient with 1 (or -1 for contrast)
logit_mask = -1 * torch.ones_like(logits)
logit_mask[0, predicted_label_idx] = 1
logits.backward(logit_mask)

# since attnLRP modified the gradient computation we can now read the relevance off the .grad attribute
img_attention_map = inputs.pixel_values.grad[0].sum(0) # sum over RGB channels for per-pixel relevance
txt_attention_map = inputs_embeds.grad[0].sum(-1) # sum over embedding dim for per-token relevance

# normalize the maps to [-1, 1]
img_attention_map = img_attention_map / abs(img_attention_map).max()
txt_attention_map = txt_attention_map / abs(txt_attention_map).max()

# %%
plt.title(f"{question} - {predicted_label} vs. <all>")
plt.imshow(img_attention_map, cmap='bwr', vmin=-1, vmax=1)
plt.show()
colorize(txt_tokens, txt_attention_map)
# Out:
# <span style="color: black; background-color: #8080ff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ececff">&nbspare&nbsp</span><span style="color: black; background-color: #e6e6ff">&nbspthose&nbsp</span><span style="color: black; background-color: #2e2eff">&nbspcats&nbsp</span><span style="color: black; background-color: #0000ff">&nbspor&nbsp</span><span style="color: black; background-color: #2c2cff">&nbspdogs&nbsp</span><span style="color: black; background-color: #f8f8ff">&nbsp?&nbsp</span><span style="color: black; background-color: #fafaff">&nbsp[SEP]&nbsp</span>

# %% [markdown]
# ## Analysis
# It seems like the text input is never positively relevant for predicting cats and there are background patches which are more relevant than the actual cat content --> Is the model exploiting noise?

# %%
# first build a convenience function
def attribute(text:str, image:Image, target:str=None, contrast:list[str]=None):
    
    # prepare inputs
    encoding = processor(image, text, return_tensors="pt")
    txt_tokens = processor.tokenizer.batch_decode(encoding.input_ids[0])
    # enable gradient for inputs to collect relevance
    encoding.pixel_values.requires_grad = True
    inputs_embeds = adapted_model.get_input_embeddings()(encoding.input_ids).requires_grad_(True)
    
    # forward pass
    outputs = adapted_model(inputs_embeds=inputs_embeds, 
                 pixel_values=encoding.pixel_values, 
                 token_type_ids=encoding.token_type_ids, 
                 attention_mask=encoding.attention_mask, 
                 pixel_mask=encoding.pixel_mask)
    logits = outputs.logits
    max_logit, predicted_class_idx = logits.max(-1)
    predicted_label = adapted_model.config.id2label[predicted_class_idx.item()]

    if contrast == 'all':
        # set all labels as contrasting targets
        logit_mask = -1 * torch.ones_like(logits)
    else:
        # set all labels to neutral
        logit_mask = torch.zeros_like(logits)
    
    # set target
    if target:
        class_idx = adapted_model.config.label2id[target]
        print(f"rel {target}: {logits[0, class_idx].item():.2f}")
    else:
        # default to max logit
        class_idx = predicted_class_idx.item()
        print(f"rel {predicted_label}: {logits[0, class_idx].item():.2f}")
    logit_mask[0, class_idx] = 1
    
    # set contrasting targets
    if type(contrast) is list:
        for target in contrast:
            target_class_idx = adapted_model.config.label2id[target]
            print(f"rel {target}: {logits[0, target_class_idx].item():.2f}")
            logit_mask[0, target_class_idx] = -1

    logits.backward(logit_mask)
    
    # normalize the heatmap
    img_attention_map = encoding.pixel_values.grad[0].sum(0) # sum RGB channels for pixel-wise relevance
    txt_attention_map = inputs_embeds.grad[0].sum(-1) # sum embedding dim for token-wise relevance
    print(f"abs_rel img: {img_attention_map.abs().sum().item():.2f}, abs_rel txt: {txt_attention_map.abs().sum().item():.2f}")
    #img_attention_map = img_attention_map / max(abs(img_attention_map).max(), abs(txt_attention_map).max())
    #txt_attention_map = txt_attention_map / max(abs(img_attention_map).max(), abs(txt_attention_map).max())
    img_attention_map = img_attention_map / abs(img_attention_map).max()
    txt_attention_map = txt_attention_map / abs(txt_attention_map).max()

    plt.title(f"{text}\n pred: {predicted_label}, target: {adapted_model.config.id2label[class_idx]}, contrast: {contrast}")
    plt.imshow(img_attention_map, cmap='bwr', vmin=-1, vmax=1)
    plt.colorbar()
    plt.show()

    return colorize(txt_tokens, txt_attention_map, adapted_model.config.id2label[class_idx])

# %%
attribute("", image)
# Out:
# rel cat: -0.51
# abs_rel img: 12.44, abs_rel txt: 0.75
# <span style="color: black; background-color: #ff0000">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ffeeee">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspcat&nbsp</span>

# %%
attribute("", image, target="cat", contrast=['dog'])
# Out:
# rel cat: -0.51
# rel dog: -6.58
# abs_rel img: 9.40, abs_rel txt: 0.59
# <span style="color: black; background-color: #ff0000">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #fff0f0">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspcat&nbsp</span>

# %%
attribute("", image, target="dog", contrast=['cat'])
# Out:
# rel dog: -6.58
# rel cat: -0.51
# abs_rel img: 9.40, abs_rel txt: 0.59
# <span style="color: black; background-color: #0000ff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #f0f0ff">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspdog&nbsp</span>

# %%
attribute("are there remotes?", image)
# Out:
# rel yes: 6.96
# abs_rel img: 0.16, abs_rel txt: 0.18
# <span style="color: black; background-color: #8686ff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ffd2d2">&nbspare&nbsp</span><span style="color: black; background-color: #ff9292">&nbspthere&nbsp</span><span style="color: black; background-color: #ff0000">&nbspremote&nbsp</span><span style="color: black; background-color: #ffe2e2">&nbsp##s&nbsp</span><span style="color: black; background-color: #ff0e0e">&nbsp?&nbsp</span><span style="color: black; background-color: #ffeaea">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspyes&nbsp</span>

# %%
attribute("are these dogs or cats?", image, contrast="all")
# Out:
# rel cats: 2.16
# abs_rel img: 888.54, abs_rel txt: 1659.28
# <span style="color: black; background-color: #8c8cff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #f0f0ff">&nbspare&nbsp</span><span style="color: black; background-color: #dedeff">&nbspthese&nbsp</span><span style="color: black; background-color: #6e6eff">&nbspdogs&nbsp</span><span style="color: black; background-color: #0000ff">&nbspor&nbsp</span><span style="color: black; background-color: #1212ff">&nbspcats&nbsp</span><span style="color: black; background-color: #f8f8ff">&nbsp?&nbsp</span><span style="color: black; background-color: #fafaff">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspcats&nbsp</span>

# %%
attribute("what is there?", image, target="remote", contrast="all")
# Out:
# rel remote: -0.85
# abs_rel img: 4341.37, abs_rel txt: 567.22
# <span style="color: black; background-color: #0000ff">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #b8b8ff">&nbspwhat&nbsp</span><span style="color: black; background-color: #eeeeff">&nbspis&nbsp</span><span style="color: black; background-color: #bcbcff">&nbspthere&nbsp</span><span style="color: black; background-color: #f8f8ff">&nbsp?&nbsp</span><span style="color: black; background-color: #ececff">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspremote&nbsp</span>

# %%
attribute("what is there?", image, target="remote", contrast=["dog", "cat"])
# Out:
# rel remote: -0.85
# rel dog: -5.90
# rel cat: 0.13
# abs_rel img: 15.84, abs_rel txt: 1.96
# <span style="color: black; background-color: #ff0000">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ffbaba">&nbspwhat&nbsp</span><span style="color: black; background-color: #fff0f0">&nbspis&nbsp</span><span style="color: black; background-color: #ffb4b4">&nbspthere&nbsp</span><span style="color: black; background-color: #fff6f6">&nbsp?&nbsp</span><span style="color: black; background-color: #ffecec">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspremote&nbsp</span>

# %%
attribute("on the sofa - cat or remote", image)
# Out:
# rel remote: -0.58
# abs_rel img: 6.76, abs_rel txt: 4.04
# <span style="color: black; background-color: #ffa0a0">&nbsp[CLS]&nbsp</span><span style="color: black; background-color: #ffecec">&nbspon&nbsp</span><span style="color: black; background-color: #fff6f6">&nbspthe&nbsp</span><span style="color: black; background-color: #ffaeae">&nbspsofa&nbsp</span><span style="color: black; background-color: #fff2f2">&nbsp-&nbsp</span><span style="color: black; background-color: #ff7676">&nbspcat&nbsp</span><span style="color: black; background-color: #ff0000">&nbspor&nbsp</span><span style="color: black; background-color: #ff3838">&nbspremote&nbsp</span><span style="color: black; background-color: #fff8f8">&nbsp[SEP]&nbsp</span><span style="color: black; background-color: lime">&nbspremote&nbsp</span>

# %%
from torch.func import jacrev, functional_call

encoding = processor(image, "what is this?", return_tensors="pt")
txt_tokens = processor.tokenizer.batch_decode(encoding.input_ids[0])
# enable gradient for inputs to collect relevance
encoding.pixel_values.requires_grad = True
inputs_embeds = adapted_model.get_input_embeddings()(encoding.input_ids).requires_grad_(True)

# Define a pure function for jacrev
# It must take the tensors we want gradients for as arguments
def predict_logits(pixel_values, inputs_embeds, params, buffers):
    # functional_call maps the dict of params/buffers to the model's forward
    outputs = functional_call(adapted_model, (params, buffers), 
                              args=(), 
                              kwargs={'pixel_values': pixel_values, 'inputs_embeds': inputs_embeds})
    return outputs.logits[0] # Return [num_logits] for a single sample

# Extract parameters and buffers
params = dict(adapted_model.named_parameters())
buffers = dict(adapted_model.named_buffers())

# Compute Jacobian (batched relevance)
jacobian = jacrev(predict_logits, argnums=0)(encoding.pixel_values, inputs_embeds, params, buffers)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[415], line 23
#      20 buffers = dict(adapted_model.named_buffers())
#      22 # Compute Jacobian (batched relevance)
# ---> 23 jacobian = jacrev(predict_logits, argnums=0)(encoding.pixel_values, inputs_embeds, params, buffers)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:570, in jacrev.<locals>.wrapper_fn(*args)
#     567 @wraps(func)
#     568 def wrapper_fn(*args):
#     569     error_if_complex("jacrev", args, is_input=True)
# --> 570     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     571     if has_aux:
#     572         output, vjp_fn, aux = vjp_out
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:358, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     356     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     357     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 358 primals_out = func(*primals)
#     360 if has_aux:
#     361     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# Cell In[415], line 13, in predict_logits(pixel_values, inputs_embeds, params, buffers)
#      11 def predict_logits(pixel_values, inputs_embeds, params, buffers):
#      12     # functional_call maps the dict of params/buffers to the model's forward
# ---> 13     outputs = functional_call(adapted_model, (params, buffers),
#      14                               args=(),
#      15                               kwargs={'pixel_values': pixel_values, 'inputs_embeds': inputs_embeds})
#      16     return outputs.logits[0]
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/_functorch/functional_call.py:148, in functional_call(module, parameter_and_buffer_dicts, args, kwargs, tie_weights, strict)
#     142 else:
#     143     raise ValueError(
#     144         f"Expected parameter_and_buffer_dicts to be a dict, or a list/tuple of dicts, "
#     145         f"but got {type(parameter_and_buffer_dicts)}"
#     146     )
# --> 148 return nn.utils.stateless._functional_call(
#     149     module,
#     150     parameters_and_buffers,
#     151     args,
#     152     kwargs,
#     153     tie_weights=tie_weights,
#     154     strict=strict,
#     155 )
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/utils/stateless.py:282, in _functional_call(module, parameters_and_buffers, args, kwargs, tie_weights, strict)
#     278     args = (args,)
#     279 with _reparametrize_module(
#     280     module, parameters_and_buffers, tie_weights=tie_weights, strict=strict
#     281 ):
# --> 282     return module(*args, **kwargs)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/lxt/explicit/models/vilt.py:1017, in ViltForQuestionAnswering.forward(self, input_ids, attention_mask, token_type_ids, pixel_values, pixel_mask, head_mask, inputs_embeds, image_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     982 r"""
#     983 image_embeds (`torch.FloatTensor` of shape `(batch_size, num_patches, hidden_size)`, *optional*):
#     984     Optionally, instead of passing `pixel_values`, you can choose to directly pass an embedded representation.
#    (...)   1013 Predicted answer: 2
#    1014 ```"""
#    1015 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1017 outputs = self.vilt(
#    1018     input_ids,
#    1019     attention_mask=attention_mask,
#    1020     token_type_ids=token_type_ids,
#    1021     pixel_values=pixel_values,
#    1022     pixel_mask=pixel_mask,
#    1023     head_mask=head_mask,
#    1024     inputs_embeds=inputs_embeds,
#    1025     image_embeds=image_embeds,
#    1026     output_attentions=output_attentions,
#    1027     output_hidden_states=output_hidden_states,
#    1028     return_dict=return_dict,
#    1029 )
#    1031 pooler_output = outputs.pooler_output if return_dict else outputs[1]
#    1033 logits = self.classifier(pooler_output)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/lxt/explicit/models/vilt.py:711, in ViltModel.forward(self, input_ids, attention_mask, token_type_ids, pixel_values, pixel_mask, head_mask, inputs_embeds, image_embeds, image_token_type_idx, output_attentions, output_hidden_states, return_dict)
#     704 # Prepare head mask if needed
#     705 # 1.0 in head_mask indicate we keep the head
#     706 # attention_probs has shape bsz x n_heads x N x N
#     707 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     708 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     709 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 711 embedding_output, attention_mask = self.embeddings(
#     712     input_ids,
#     713     attention_mask,
#     714     token_type_ids,
#     715     pixel_values,
#     716     pixel_mask,
#     717     inputs_embeds,
#     718     image_embeds,
#     719     image_token_type_idx=image_token_type_idx,
#     720 )
#     722 # We can provide a self-attention mask of dimensions [batch_size, from_seq_length, to_seq_length]
#     723 # ourselves in which case we just need to make it broadcastable to all heads.
#     724 extended_attention_mask: torch.Tensor = self.get_extended_attention_mask(attention_mask, input_shape)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/lxt/explicit/models/vilt.py:224, in ViltEmbeddings.forward(self, input_ids, attention_mask, token_type_ids, pixel_values, pixel_mask, inputs_embeds, image_embeds, image_token_type_idx)
#     212 def forward(
#     213     self,
#     214     input_ids,
#    (...)    222 ):
#     223     # PART 1: text embeddings
# --> 224     text_embeds = self.text_embeddings(
#     225         input_ids=input_ids, token_type_ids=token_type_ids, inputs_embeds=inputs_embeds
#     226     )
#     228     # PART 2: patch embeddings (with interpolated position encodings)
#     229     if image_embeds is None:
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/lxt/explicit/models/vilt.py:302, in TextEmbeddings.forward(self, input_ids, token_type_ids, position_ids, inputs_embeds)
#     299     inputs_embeds = self.word_embeddings(input_ids)
#     300 token_type_embeddings = self.token_type_embeddings(token_type_ids)
# --> 302 embeddings = lf.add2(inputs_embeds, token_type_embeddings) # <----------- LXT
#     303 if self.position_embedding_type == "absolute":
#     304     position_embeddings = self.position_embeddings(position_ids)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/lxt/explicit/functional.py:67, in add2(input_a, input_b, inplace, epsilon)
#      50 @torch.fx.wrap
#      51 def add2(input_a, input_b, inplace=False, epsilon=1e-8):
#      52     """
#      53     Standard Epsilon-LRP rule for elementwise addition (along all dimensions) of two tensors according to the Equation 8 of the paper
#      54     'AttnLRP: Attention-Aware Layer-wise Relevance Propagation for Transformers'
#    (...)     65         Small value to stabilize the denominator
#      66     """
# ---> 67     return add2_tensors_fn.apply(input_a, input_b, inplace, epsilon)
#
# File /scratch/koegel/.conda-envs/playground/lib/python3.12/site-packages/torch/autograd/function.py:579, in Function.apply(cls, *args, **kwargs)
#     576     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     578 if not is_setup_ctx_defined:
# --> 579     raise RuntimeError(
#     580         "In order to use an autograd.Function with functorch transforms "
#     581         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     582         "staticmethod. For more details, please see "
#     583         "https://pytorch.org/docs/main/notes/extending.func.html"
#     584     )
#     586 return custom_function_call(cls, *args, **kwargs)
#
# RuntimeError: In order to use an autograd.Function with functorch transforms (vmap, grad, jvp, jacrev, ...), it must override the setup_context staticmethod. For more details, please see https://pytorch.org/docs/main/notes/extending.func.html

# %%
encoding = processor(image, "what is this?", return_tensors="pt")
txt_tokens = processor.tokenizer.batch_decode(encoding.input_ids[0])
# enable gradient for inputs to collect relevance
encoding.pixel_values.requires_grad = True
inputs_embeds = adapted_model.get_input_embeddings()(encoding.input_ids).requires_grad_(True)

# forward pass
outputs = adapted_model(inputs_embeds=inputs_embeds, 
             pixel_values=encoding.pixel_values, 
             token_type_ids=encoding.token_type_ids, 
             attention_mask=encoding.attention_mask, 
             pixel_mask=encoding.pixel_mask)
logits = outputs.logits
max_logit, predicted_class_idx = logits.max(-1)
predicted_label = adapted_model.config.id2label[predicted_class_idx.item()]

img_maps = torch.empty((logits.shape[1], *encoding.pixel_values.shape[2:]))
txt_maps = torch.empty((logits.shape[1], inputs_embeds.shape[1]))
for i, row in tqdm(enumerate(torch.eye(logits.shape[1]))):
    logits.backward(row[None, :], retain_graph=True)
    img_maps[i] = encoding.pixel_values.grad[0].sum(0).detach()
    encoding.pixel_values.grad = None
    txt_maps[i] = inputs_embeds.grad[0].sum(-1).detach()
    inputs_embeds.grad = None
# Out:
# 3129it [1:03:09,  1.21s/it]

# %%
predicted_label
# Out:
# 'cat'

# %%
# np.save('testsample_img_maps.npy', img_maps.numpy())
# np.save('testsample_txt_maps.npy', txt_maps.numpy())

# %%
# let's analyse the suspicious patch
for rel, idx in zip(*img_maps[:, -32:, 96:128].mean(dim=(1,2)).topk(20)):
    print(rel, adapted_model.config.id2label[idx.item()])
# Out:
# tensor(0.0001) cat
# tensor(-2.5400e-06) 6:05
# tensor(-2.8489e-06) 6:20
# tensor(-2.9726e-06) 8:35
# tensor(-3.0327e-06) 6:25
# tensor(-3.0539e-06) 9:35
# tensor(-3.1249e-06) 12:25
# tensor(-3.1956e-06) 7:25
# tensor(-3.2173e-06) 7:35
# tensor(-3.2702e-06) 4:05
# tensor(-3.4619e-06) 8:05
# tensor(-3.4647e-06) 2:05
# tensor(-3.4869e-06) 1:05
# tensor(-3.5237e-06) 12:28
# tensor(-3.6659e-06) 3:10
# tensor(-3.6713e-06) 8:55
# tensor(-3.7111e-06) 7:05
# tensor(-3.7247e-06) 6:45
# tensor(-3.8189e-06) 10:35
# tensor(-3.8212e-06) 10:08

# %%
data = img_maps[:, -32:, 96:128].mean(dim=(1,2)).topk(20)
plt.bar([adapted_model.config.id2label[i.item()] for i in data.indices], data.values)
plt.xticks(rotation=90, ha='center');

# %%
adapted_model.config.id2label[img_maps.sum((1,2)).argmax(0).item()]
# Out:
# 'remote control'

# %%
rels, idxs = img_maps.reshape(-1, img_maps.shape[1]//32, 32, img_maps.shape[2]//32, 32).mean(dim=(2,4)).max(0)
plt.figure(figsize=(12,12))
plt.imshow(rels, cmap='bwr')
for x,y in np.ndindex(idxs.shape):
    plt.gca().text(y, x, adapted_model.config.id2label[idxs[x, y].item()], 
                ha="center", va="center", fontsize=8, color='white', rotation=30)

# %%
rels, idxs = txt_maps.max(0)
colorize([adapted_model.config.id2label[idx.item()] for idx in idxs], rels)
# Out:
# <span style="color: black; background-color: #ff8a8a">&nbspremote&nbsp</span><span style="color: black; background-color: #ffdada">&nbspremote control&nbsp</span><span style="color: black; background-color: #fff6f6">&nbspremote control&nbsp</span><span style="color: black; background-color: #ffd4d4">&nbspremote control&nbsp</span><span style="color: black; background-color: #fffcfc">&nbspremote&nbsp</span><span style="color: black; background-color: #fff8f8">&nbspremote&nbsp</span>

# %%
idxs.shape
# Out:
# torch.Size([12, 16])

# %%
img_maps.shape
# Out:
# torch.Size([3129, 384, 512])

# %%
# normalize the heatmap
img_attention_map = encoding.pixel_values.grad[0].sum(0) # sum RGB channels for pixel-wise relevance
txt_attention_map = inputs_embeds.grad[0].sum(-1) # sum embedding dim for token-wise relevance
print(f"abs_rel img: {img_attention_map.abs().sum().item():.2f}, abs_rel txt: {txt_attention_map.abs().sum().item():.2f}")
#img_attention_map = img_attention_map / max(abs(img_attention_map).max(), abs(txt_attention_map).max())
#txt_attention_map = txt_attention_map / max(abs(img_attention_map).max(), abs(txt_attention_map).max())
img_attention_map = img_attention_map / abs(img_attention_map).max()
txt_attention_map = txt_attention_map / abs(txt_attention_map).max()

plt.title(f"{text}\n pred: {predicted_label}, target: {adapted_model.config.id2label[class_idx]}, contrast: {contrast}")
plt.imshow(img_attention_map, cmap='bwr', vmin=-1, vmax=1)
plt.colorbar()
plt.show()

return colorize(txt_tokens, txt_attention_map, adapted_model.config.id2label[class_idx])
